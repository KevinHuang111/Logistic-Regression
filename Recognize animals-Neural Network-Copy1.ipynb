# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils import summary, comparator

# %matplotlib inline
np.random.seed(1)

# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical   


(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
import matplotlib.pyplot as plt

cifar_classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
print('Example training images and their labels: ' + str([x[0] for x in y_train[0:5]])) 
print('Corresponding classes for the labels: ' + str([cifar_classes[x[0]] for x in y_train[0:10]]))

f, axarr = plt.subplots(1, 10)
f.set_size_inches(16, 6)

for i in range(10):
    img = X_train[i]
    axarr[i].imshow(img)
plt.show()
# Out:
# Example training images and their labels: [6, 9, 9, 4, 1]
# Corresponding classes for the labels: ['frog', 'truck', 'truck', 'deer', 'automobile', 'automobile', 'bird', 'horse', 'ship', 'cat']

# %%
X_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
m_train = X_train.shape[0]
m_test = y_train.shape[0]
num_px = X_train.shape[1]



print ("Number of training examples: m_train = " + str(m_train))
print ("Number of testing examples: m_test = " + str(m_test))
print ("Height/Width of each image: num_px = " + str(num_px))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_set_x shape: " + str(X_train.shape))
print ("train_set_y shape: " + str(y_train.shape))
print ("test_set_x shape: " + str(X_test.shape))
print ("test_set_y shape: " + str(y_test.shape))
# Out:
# Number of training examples: m_train = 50000
# Number of testing examples: m_test = 50000
# Height/Width of each image: num_px = 32
# Each image is of size: (32, 32, 3)
# train_set_x shape: (50000, 32, 32, 3)
# train_set_y shape: (50000, 1)
# test_set_x shape: (10000, 32, 32, 3)
# test_set_y shape: (10000, 1)

# %%
x_train = X_train/255.
x_test = X_test/255.
Y_train = convert_to_one_hot(y_train, 11).T
Y_test = convert_to_one_hot(y_test, 11).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 50000
# number of test examples = 10000
# X_train shape: (50000, 32, 32, 3)
# Y_train shape: (50000, 11)
# X_test shape: (10000, 32, 32, 3)
# Y_test shape: (10000, 11)

# %%
# GRADED FUNCTION: convolutional_model

def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """

    input_img = tf.keras.Input(shape=input_shape)
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    # Z1 = None
    ## RELU
    # A1 = None
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    # P1 = None
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    # Z2 = None
    ## RELU
    # A2 = None
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    # P2 = None
    ## FLATTEN
    # F = None
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    # outputs = None
    # YOUR CODE STARTS HERE
    Z1 = tfl.Conv2D(8, 4, activation='linear', padding="same", strides=1)(input_img)
    A1 = tfl.ReLU()(Z1)
    P1 = tfl.MaxPool2D(pool_size=(8, 8), strides=(8, 8), padding='same')(A1)
    Z2 = tfl.Conv2D(16, 2, activation='linear', padding="same", strides=1)(P1)
    A2 = tfl.ReLU()(Z2)
    P2 = tfl.MaxPool2D(pool_size=(4, 4), strides=(4, 4), padding='same')(A2)
    F = tfl.Flatten()(P2)
    outputs = tfl.Dense(11, activation='softmax')(F)
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((32, 32, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
    
output = [['InputLayer', [(None, 32, 32, 3)], 0],
        ['Conv2D', (None, 32, 32, 8), 392, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 32, 32, 8), 0],
        ['MaxPooling2D', (None, 8, 8, 8), 0, (8, 8), (8, 8), 'same'],
        ['Conv2D', (None, 8, 8, 16), 528, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 8, 8, 16), 0],
        ['MaxPooling2D', (None, 2, 2, 16), 0, (4, 4), (4, 4), 'same'],
        ['Flatten', (None, 64), 0],
        ['Dense', (None, 11), 390, 'softmax']]
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 8)         392
#
#  re_lu_6 (ReLU)              (None, 32, 32, 8)         0
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 8)          0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 16)          528
#
#  re_lu_7 (ReLU)              (None, 4, 4, 16)          0
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 16)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 11)                187
#
# =================================================================
# Total params: 1,107
# Trainable params: 1,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, Y_train)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, Y_test)).batch(32)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 14s 8ms/step - loss: 2.1068 - accuracy: 0.2186 - val_loss: 1.9204 - val_accuracy: 0.2969
# Epoch 2/100
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.8276 - accuracy: 0.3337 - val_loss: 1.7489 - val_accuracy: 0.3731
# Epoch 3/100
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.7164 - accuracy: 0.3794 - val_loss: 1.6808 - val_accuracy: 0.3993
# Epoch 4/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6607 - accuracy: 0.3985 - val_loss: 1.6398 - val_accuracy: 0.4106
# Epoch 5/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6225 - accuracy: 0.4146 - val_loss: 1.6082 - val_accuracy: 0.4180
# Epoch 6/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5914 - accuracy: 0.4260 - val_loss: 1.5777 - val_accuracy: 0.4270
# Epoch 7/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5623 - accuracy: 0.4365 - val_loss: 1.5512 - val_accuracy: 0.4409
# Epoch 8/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5367 - accuracy: 0.4469 - val_loss: 1.5284 - val_accuracy: 0.4504
# Epoch 9/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5155 - accuracy: 0.4535 - val_loss: 1.5075 - val_accuracy: 0.4585
# Epoch 10/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4975 - accuracy: 0.4606 - val_loss: 1.4916 - val_accuracy: 0.4649
# Epoch 11/100
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.4828 - accuracy: 0.4675 - val_loss: 1.4798 - val_accuracy: 0.4699
# Epoch 12/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4705 - accuracy: 0.4731 - val_loss: 1.4703 - val_accuracy: 0.4703
# Epoch 13/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.4603 - accuracy: 0.4778 - val_loss: 1.4599 - val_accuracy: 0.4769
# Epoch 14/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4514 - accuracy: 0.4806 - val_loss: 1.4544 - val_accuracy: 0.4806
# Epoch 15/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4437 - accuracy: 0.4836 - val_loss: 1.4474 - val_accuracy: 0.4827
# Epoch 16/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4370 - accuracy: 0.4852 - val_loss: 1.4411 - val_accuracy: 0.4836
# Epoch 17/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4313 - accuracy: 0.4879 - val_loss: 1.4378 - val_accuracy: 0.4862
# Epoch 18/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.4262 - accuracy: 0.4899 - val_loss: 1.4347 - val_accuracy: 0.4875
# Epoch 19/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.4217 - accuracy: 0.4922 - val_loss: 1.4320 - val_accuracy: 0.4882
# Epoch 20/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4178 - accuracy: 0.4934 - val_loss: 1.4265 - val_accuracy: 0.4909
# Epoch 21/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4142 - accuracy: 0.4951 - val_loss: 1.4239 - val_accuracy: 0.4920
# Epoch 22/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4108 - accuracy: 0.4966 - val_loss: 1.4219 - val_accuracy: 0.4924
# Epoch 23/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4080 - accuracy: 0.4972 - val_loss: 1.4199 - val_accuracy: 0.4916
# Epoch 24/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.4054 - accuracy: 0.4986 - val_loss: 1.4178 - val_accuracy: 0.4918
# Epoch 25/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4027 - accuracy: 0.4996 - val_loss: 1.4159 - val_accuracy: 0.4940
# Epoch 26/100
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.4003 - accuracy: 0.5012 - val_loss: 1.4147 - val_accuracy: 0.4959
# Epoch 27/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3971 - accuracy: 0.5023 - val_loss: 1.4144 - val_accuracy: 0.4966
# Epoch 28/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3943 - accuracy: 0.5042 - val_loss: 1.4125 - val_accuracy: 0.4964
# Epoch 29/100
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.3916 - accuracy: 0.5053 - val_loss: 1.4112 - val_accuracy: 0.4940
# Epoch 30/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3889 - accuracy: 0.5060 - val_loss: 1.4083 - val_accuracy: 0.4968
# Epoch 31/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3863 - accuracy: 0.5073 - val_loss: 1.4066 - val_accuracy: 0.4983
# Epoch 32/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3837 - accuracy: 0.5076 - val_loss: 1.4043 - val_accuracy: 0.5009
# Epoch 33/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3813 - accuracy: 0.5079 - val_loss: 1.4021 - val_accuracy: 0.5012
# Epoch 34/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3789 - accuracy: 0.5087 - val_loss: 1.3990 - val_accuracy: 0.5031
# Epoch 35/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3767 - accuracy: 0.5096 - val_loss: 1.4004 - val_accuracy: 0.5029
# Epoch 36/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3746 - accuracy: 0.5096 - val_loss: 1.3982 - val_accuracy: 0.5043
# Epoch 37/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3727 - accuracy: 0.5100 - val_loss: 1.3962 - val_accuracy: 0.5052
# Epoch 38/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3709 - accuracy: 0.5122 - val_loss: 1.3951 - val_accuracy: 0.5066
# Epoch 39/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3692 - accuracy: 0.5120 - val_loss: 1.3927 - val_accuracy: 0.5057
# Epoch 40/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3677 - accuracy: 0.5125 - val_loss: 1.3904 - val_accuracy: 0.5067
# Epoch 41/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3661 - accuracy: 0.5129 - val_loss: 1.3900 - val_accuracy: 0.5076
# Epoch 42/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3648 - accuracy: 0.5131 - val_loss: 1.3879 - val_accuracy: 0.5084
# Epoch 43/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3632 - accuracy: 0.5134 - val_loss: 1.3863 - val_accuracy: 0.5088
# Epoch 44/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3616 - accuracy: 0.5136 - val_loss: 1.3855 - val_accuracy: 0.5090
# Epoch 45/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3602 - accuracy: 0.5140 - val_loss: 1.3861 - val_accuracy: 0.5070
# Epoch 46/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3588 - accuracy: 0.5150 - val_loss: 1.3855 - val_accuracy: 0.5081
# Epoch 47/100
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.3575 - accuracy: 0.5158 - val_loss: 1.3836 - val_accuracy: 0.5083
# Epoch 48/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3562 - accuracy: 0.5149 - val_loss: 1.3822 - val_accuracy: 0.5076
# Epoch 49/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3548 - accuracy: 0.5151 - val_loss: 1.3818 - val_accuracy: 0.5076
# Epoch 50/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3533 - accuracy: 0.5155 - val_loss: 1.3820 - val_accuracy: 0.5074
# Epoch 51/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3519 - accuracy: 0.5164 - val_loss: 1.3817 - val_accuracy: 0.5077
# Epoch 52/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3505 - accuracy: 0.5181 - val_loss: 1.3809 - val_accuracy: 0.5080
# Epoch 53/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3492 - accuracy: 0.5181 - val_loss: 1.3790 - val_accuracy: 0.5082
# Epoch 54/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3479 - accuracy: 0.5184 - val_loss: 1.3783 - val_accuracy: 0.5082
# Epoch 55/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3466 - accuracy: 0.5180 - val_loss: 1.3767 - val_accuracy: 0.5079
# Epoch 56/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3453 - accuracy: 0.5186 - val_loss: 1.3767 - val_accuracy: 0.5082
# Epoch 57/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3441 - accuracy: 0.5190 - val_loss: 1.3727 - val_accuracy: 0.5085
# Epoch 58/100
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.3429 - accuracy: 0.5201 - val_loss: 1.3720 - val_accuracy: 0.5087
# Epoch 59/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3418 - accuracy: 0.5201 - val_loss: 1.3711 - val_accuracy: 0.5092
# Epoch 60/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3408 - accuracy: 0.5204 - val_loss: 1.3703 - val_accuracy: 0.5103
# Epoch 61/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3399 - accuracy: 0.5198 - val_loss: 1.3705 - val_accuracy: 0.5112
# Epoch 62/100
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.3389 - accuracy: 0.5210 - val_loss: 1.3685 - val_accuracy: 0.5138
# Epoch 63/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3379 - accuracy: 0.5209 - val_loss: 1.3669 - val_accuracy: 0.5133
# Epoch 64/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3370 - accuracy: 0.5217 - val_loss: 1.3664 - val_accuracy: 0.5138
# Epoch 65/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3362 - accuracy: 0.5224 - val_loss: 1.3673 - val_accuracy: 0.5129
# Epoch 66/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3354 - accuracy: 0.5224 - val_loss: 1.3659 - val_accuracy: 0.5144
# Epoch 67/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3345 - accuracy: 0.5223 - val_loss: 1.3651 - val_accuracy: 0.5159
# Epoch 68/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3337 - accuracy: 0.5234 - val_loss: 1.3640 - val_accuracy: 0.5180
# Epoch 69/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3329 - accuracy: 0.5233 - val_loss: 1.3638 - val_accuracy: 0.5186
# Epoch 70/100
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3321 - accuracy: 0.5234 - val_loss: 1.3631 - val_accuracy: 0.5189
# Epoch 71/100
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.3314 - accuracy: 0.5240 - val_loss: 1.3630 - val_accuracy: 0.5196
# Epoch 72/100
#  933/1563 [================>.............] - ETA: 3s - loss: 1.3254 - accuracy: 0.5261
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26660\1128264140.py in <module>
#       1 train_dataset = tf.data.Dataset.from_tensor_slices((x_train, Y_train)).batch(32)
#       2 test_dataset = tf.data.Dataset.from_tensor_slices((x_test, Y_test)).batch(32)
# ----> 3 history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
